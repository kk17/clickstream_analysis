# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark import SparkConf
import pandas as pd

# %%
spark = SparkSession.builder.getOrCreate()

# %%
# %ls /opt/spark-data
# Out:
# clickstream-sample.json*

# %%
df = spark.read.json("/opt/spark-data/clickstream-sample.json")

# %%
df.count()
# Out:
# 14834

# %%
df.printSchema()
# Out:
# root
#  |-- age: string (nullable = true)
#  |-- birthday: string (nullable = true)
#  |-- cart_amount: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- crossPlatform: boolean (nullable = true)
#  |-- current_url: string (nullable = true)
#  |-- custom_attributes: struct (nullable = true)
#  |    |-- AdidasPageCount: long (nullable = true)
#  |    |-- BasketItemCount: long (nullable = true)
#  |    |-- Bizim_Hikaye: long (nullable = true)
#  |    |-- Device: string (nullable = true)
#  |    |-- DeviceType: string (nullable = true)
#  |    |-- First_Location: string (nullable = true)
#  |    |-- HacveUmre: boolean (nullable = true)
#  |    |-- Kadin: long (nullable = true)
#  |    |-- KadinPageCount: long (nullable = true)
#  |    |-- LastPurchasedCategories: string (nullable = true)
#  |    |-- LastPurchasedItems: string (nullable = true)
#  |    |-- LastVisitDate_LastXDays: long (nullable = true)
#  |    |-- LastVisitedCategories: string (nullable = true)
#  |    |-- LastVisitedProduct: string (nullable = true)
#  |    |-- LastvisitedPage: string (nullable = true)
#  |    |-- Location: string (nullable = true)
#  |    |-- NikePageCount: long (nullable = true)
#  |    |-- PageCountcanta: long (nullable = true)
#  |    |-- Second_Location: string (nullable = true)
#  |    |-- Sevkat_Yerimdar: long (nullable = true)
#  |    |-- Third_Location: string (nullable = true)
#  |    |-- UcakSayfasi: boolean (nullable = true)
#  |    |-- UserCity: string (nullable = true)
#  |    |-- UserCountry: string (nullable = true)
#  |    |-- UserDestination: string (nullable = true)
#  |    |-- UserEmail: string (nullable = true)
#  |    |-- UserIpAddress: string (nullable = true)
#  |    |-- UserIsNew: boolean (nullable = true)
#  |    |-- UserIsReturning: boolean (nullable = true)
#  |    |-- UserKfStatus: string (nullable = true)
#  |    |-- UserLoggedIn: boolean (nullable = true)
#  |    |-- UserOrigin: string (nullable = true)
#  |    |-- UserPointOfSale: string (nullable = true)
#  |    |-- UserRBD: string (nullable = true)
#  |    |-- UserTotalCartAmount: long (nullable = true)
#  |    |-- alkolsuzHizmetVerenTesisler: boolean (nullable = true)
#  |    |-- antalyaOtelleri: boolean (nullable = true)
#  |    |-- arkaSokaklar: long (nullable = true)
#  |    |-- balayiOtelleri: boolean (nullable = true)
#  |    |-- basketItemCategory: string (nullable = true)
#  |    |-- basketItemCount: string (nullable = true)
#  |    |-- basketItemImage: string (nullable = true)
#  |    |-- basketItemName: string (nullable = true)
#  |    |-- basketItemsCount: long (nullable = true)
#  |    |-- benBilmemEsimBilirTv: long (nullable = true)
#  |    |-- bodrumOtelleri: boolean (nullable = true)
#  |    |-- bonusRouble: string (nullable = true)
#  |    |-- buyerOrNonBuyer: string (nullable = true)
#  |    |-- cSegment_BilimTeknoloji: long (nullable = true)
#  |    |-- cSegment_Bizce: long (nullable = true)
#  |    |-- cSegment_Dunya: long (nullable = true)
#  |    |-- cSegment_Egitim: long (nullable = true)
#  |    |-- cSegment_Ekonomi: long (nullable = true)
#  |    |-- cSegment_Emlak: long (nullable = true)
#  |    |-- cSegment_Galeri: long (nullable = true)
#  |    |-- cSegment_HavaDurumu: long (nullable = true)
#  |    |-- cSegment_IyilikSaglik: long (nullable = true)
#  |    |-- cSegment_KulturSanat: long (nullable = true)
#  |    |-- cSegment_Magazin: long (nullable = true)
#  |    |-- cSegment_Otomobil: long (nullable = true)
#  |    |-- cSegment_Saglik: long (nullable = true)
#  |    |-- cSegment_Sanat: long (nullable = true)
#  |    |-- cSegment_SosyalMedya: long (nullable = true)
#  |    |-- cSegment_Spor: long (nullable = true)
#  |    |-- cSegment_Teknoloji: long (nullable = true)
#  |    |-- cSegment_Turkiye: long (nullable = true)
#  |    |-- cSegment_UniversiteRehberim: long (nullable = true)
#  |    |-- cSegment_Video: long (nullable = true)
#  |    |-- cSegment_Yasam: long (nullable = true)
#  |    |-- cSegment__Dunya: long (nullable = true)
#  |    |-- cSegment__Seyahat: long (nullable = true)
#  |    |-- cSegment__Spor: long (nullable = true)
#  |    |-- cSegment_teknoloji: long (nullable = true)
#  |    |-- cocuklarDuymasin: long (nullable = true)
#  |    |-- customer_id: string (nullable = true)
#  |    |-- device: string (nullable = true)
#  |    |-- deviceType: string (nullable = true)
#  |    |-- email: string (nullable = true)
#  |    |-- erkekPageCount: long (nullable = true)
#  |    |-- fethiyeOtelleri: boolean (nullable = true)
#  |    |-- flightFrom: string (nullable = true)
#  |    |-- flightPackage: string (nullable = true)
#  |    |-- flightPassengerCount: string (nullable = true)
#  |    |-- flightTo: string (nullable = true)
#  |    |-- flightType: boolean (nullable = true)
#  |    |-- geceFirstalari: boolean (nullable = true)
#  |    |-- gender: string (nullable = true)
#  |    |-- holidayFrom: string (nullable = true)
#  |    |-- holidayPackFrom: string (nullable = true)
#  |    |-- holidayPackTo: string (nullable = true)
#  |    |-- holidayTo: string (nullable = true)
#  |    |-- insLastPurchasedProductDate: string (nullable = true)
#  |    |-- insLastPurchasedProductImage: string (nullable = true)
#  |    |-- insider_session_id: string (nullable = true)
#  |    |-- isUserIgnoredWebpush: boolean (nullable = true)
#  |    |-- isUserLoggedIn: boolean (nullable = true)
#  |    |-- isimsizlerDizi: long (nullable = true)
#  |    |-- istanbulaYakinOteller: boolean (nullable = true)
#  |    |-- kayakotelleri: boolean (nullable = true)
#  |    |-- kibrisOtelleri: boolean (nullable = true)
#  |    |-- language: string (nullable = true)
#  |    |-- lastPurchasedDate: string (nullable = true)
#  |    |-- lastPurchasedProductCategory: string (nullable = true)
#  |    |-- lastPurchasedProductDate: string (nullable = true)
#  |    |-- lastPurchasedProductImage: string (nullable = true)
#  |    |-- lastPurchasedProductName: string (nullable = true)
#  |    |-- lastVisitedCategory: string (nullable = true)
#  |    |-- lastVisitedGenderCat: string (nullable = true)
#  |    |-- lastVisitedProductImage: string (nullable = true)
#  |    |-- lastVisitedProductName: string (nullable = true)
#  |    |-- locaiton: string (nullable = true)
#  |    |-- location: string (nullable = true)
#  |    |-- magazinDTv: long (nullable = true)
#  |    |-- marmarisOtelleri: boolean (nullable = true)
#  |    |-- maxxRoyal: boolean (nullable = true)
#  |    |-- meryemDizisi: long (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- pageCountOutlet: long (nullable = true)
#  |    |-- rixosOtelleri: boolean (nullable = true)
#  |    |-- sehirOtelleri: boolean (nullable = true)
#  |    |-- siyahBeyazAsk: long (nullable = true)
#  |    |-- sonDakikaFirsatlari: boolean (nullable = true)
#  |    |-- spApiUserData: struct (nullable = true)
#  |    |    |-- email: string (nullable = true)
#  |    |    |-- email_optin: long (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- user_id: string (nullable = true)
#  |    |-- termalOteller: boolean (nullable = true)
#  |    |-- totalBasketAmount: string (nullable = true)
#  |    |-- tutsakDizisi: long (nullable = true)
#  |    |-- userCampaignStatus: boolean (nullable = true)
#  |    |-- userIpLocation: string (nullable = true)
#  |    |-- userLandCamp: boolean (nullable = true)
#  |    |-- userLocation: string (nullable = true)
#  |    |-- userSelectedCurrency: string (nullable = true)
#  |    |-- useripCity: string (nullable = true)
#  |    |-- vatanimSensin: long (nullable = true)
#  |    |-- verEliniAskDizisi: long (nullable = true)
#  |    |-- voyageOtelleri: boolean (nullable = true)
#  |    |-- yurtDisiTurlari: boolean (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- email: string (nullable = true)
#  |-- email_optin: string (nullable = true)
#  |-- event: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- init_session: boolean (nullable = true)
#  |-- ip: string (nullable = true)
#  |-- language: string (nullable = true)
#  |-- last_updated_l2p: string (nullable = true)
#  |-- mobile_device_token: string (nullable = true)
#  |-- mobile_push_optin: boolean (nullable = true)
#  |-- name: string (nullable = true)
#  |-- newUserId: string (nullable = true)
#  |-- oldUserId: string (nullable = true)
#  |-- page_type: string (nullable = true)
#  |-- partnerId: string (nullable = true)
#  |-- partner_id: string (nullable = true)
#  |-- partner_name: string (nullable = true)
#  |-- personalizations: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- platform: string (nullable = true)
#  |-- product: struct (nullable = true)
#  |    |-- category: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- imgUrl: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- price: struct (nullable = true)
#  |    |    |-- currency: string (nullable = true)
#  |    |    |-- value: double (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- products: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- category: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- imgUrl: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- price: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |-- referrer: string (nullable = true)
#  |-- search_query: string (nullable = true)
#  |-- session_id: string (nullable = true)
#  |-- surname: string (nullable = true)
#  |-- unification: boolean (nullable = true)
#  |-- user_agent: string (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- username: string (nullable = true)
#  |-- version: string (nullable = true)
#  |-- webpush_language: string (nullable = true)
#  |-- webpush_optin: boolean (nullable = true)
#  |-- webpush_token: string (nullable = true)

# %%
df.groupBy("event").count().toPandas()
# Out:
#          event  count
# 0      session   2436
# 1         user    384
# 2  unification     12
# 3     pageView  12002
